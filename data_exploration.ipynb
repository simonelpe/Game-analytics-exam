# %%
from pathlib import Path

import pandas as pd
from IPython.display import display

df = pd.read_csv("vgsales_clean.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
# convertire 'Year_of_Release' in data %Y
df['Year_of_Release'] = pd.to_datetime(df['Year_of_Release'], format='%Y', errors='coerce')
df
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii      2006-01-01        Sports
# 1                  Super Mario Bros.      NES      1985-01-01      Platform
# 2                     Mario Kart Wii      Wii      2008-01-01        Racing
# 3                  Wii Sports Resort      Wii      2009-01-01        Sports
# 4           Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3      2016-01-01        Action
# 16715               LMA Manager 2007     X360      2006-01-01        Sports
# 16716        Haitaka no Psychedelica      PSV      2016-01-01     Adventure
# 16717               Spirits & Spells      GBA      2003-01-01      Platform
# 16718            Winning Post 8 2016      PSV      2016-01-01    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
# controlla quanti null per ogni singola colonna
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# rimuoviamo righe senza anno per i grafici temporali
df = df.dropna(subset=['Year_of_Release'])
df
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii      2006-01-01        Sports
# 1                  Super Mario Bros.      NES      1985-01-01      Platform
# 2                     Mario Kart Wii      Wii      2008-01-01        Racing
# 3                  Wii Sports Resort      Wii      2009-01-01        Sports
# 4           Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3      2016-01-01        Action
# 16715               LMA Manager 2007     X360      2006-01-01        Sports
# 16716        Haitaka no Psychedelica      PSV      2016-01-01     Adventure
# 16717               Spirits & Spells      GBA      2003-01-01      Platform
# 16718            Winning Post 8 2016      PSV      2016-01-01    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16450 rows x 16 columns]

# %%
# Rimuoviamo righe gioco senza nome
df = df.dropna(subset=['Name'])
df
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii      2006-01-01        Sports
# 1                  Super Mario Bros.      NES      1985-01-01      Platform
# 2                     Mario Kart Wii      Wii      2008-01-01        Racing
# 3                  Wii Sports Resort      Wii      2009-01-01        Sports
# 4           Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3      2016-01-01        Action
# 16715               LMA Manager 2007     X360      2006-01-01        Sports
# 16716        Haitaka no Psychedelica      PSV      2016-01-01     Adventure
# 16717               Spirits & Spells      GBA      2003-01-01      Platform
# 16718            Winning Post 8 2016      PSV      2016-01-01    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16448 rows x 16 columns]

# %%
# Sostituiamo i nan in publisher con 'Unknown'
df['Publisher'] = df['Publisher'].fillna('Unknown')
df
# Out:
# C:\Users\FrancescoLamanna\AppData\Local\Temp\ipykernel_20040\588132122.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Publisher'] = df['Publisher'].fillna('Unknown')
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii      2006-01-01        Sports
# 1                  Super Mario Bros.      NES      1985-01-01      Platform
# 2                     Mario Kart Wii      Wii      2008-01-01        Racing
# 3                  Wii Sports Resort      Wii      2009-01-01        Sports
# 4           Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3      2016-01-01        Action
# 16715               LMA Manager 2007     X360      2006-01-01        Sports
# 16716        Haitaka no Psychedelica      PSV      2016-01-01     Adventure
# 16717               Spirits & Spells      GBA      2003-01-01      Platform
# 16718            Winning Post 8 2016      PSV      2016-01-01    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16448 rows x 16 columns]

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\FrancescoLamanna\AppData\Local\Temp\ipykernel_20040\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
# esporto in data.csv
df.to_csv("data.csv", index=False)

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                                    Name Platform Year_of_Release     Genre  \
# 0                            Wii Sports      Wii      2006-01-01    Sports
# 1                        Mario Kart Wii      Wii      2008-01-01    Racing
# 2                     Wii Sports Resort      Wii      2009-01-01    Sports
# 3                 New Super Mario Bros.       DS      2006-01-01  Platform
# 4                              Wii Play      Wii      2006-01-01      Misc
# ...                                 ...      ...             ...       ...
# 6821         E.T. The Extra-Terrestrial      GBA      2001-01-01    Action
# 6822     Mortal Kombat: Deadly Alliance      GBA      2002-01-01  Fighting
# 6823  Metal Gear Solid V: Ground Zeroes       PC      2014-01-01    Action
# 6824                             Breach       PC      2011-01-01   Shooter
# 6825            STORM: Frontline Nation       PC      2011-01-01  Strategy
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                         Nintendo     41.36     28.96      3.77         8.45
# 1                         Nintendo     15.68     12.76      3.79         3.29
# 2                         Nintendo     15.61     10.93      3.28         2.95
# 3                         Nintendo     11.28      9.14      6.50         2.88
# 4                         Nintendo     13.96      9.18      2.93         2.84
# ...                            ...       ...       ...       ...          ...
# 6821                      NewKidCo      0.01      0.00      0.00         0.00
# 6822                  Midway Games      0.01      0.00      0.00         0.00
# 6823  Konami Digital Entertainment      0.00      0.01      0.00         0.00
# 6824                     Destineer      0.01      0.00      0.00         0.00
# 6825                       Unknown      0.00      0.01      0.00         0.00
#
#       Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 0            82.53          76.0          51.0         8.0       322.0
# 1            35.52          82.0          73.0         8.3       709.0
# 2            32.77          80.0          73.0         8.0       192.0
# 3            29.80          89.0          65.0         8.5       431.0
# 4            28.92          58.0          41.0         6.6       129.0
# ...            ...           ...           ...         ...         ...
# 6821          0.01          46.0           4.0         2.4        21.0
# 6822          0.01          81.0          12.0         8.8         9.0
# 6823          0.01          80.0          20.0         7.6       412.0
# 6824          0.01          61.0          12.0         5.8        43.0
# 6825          0.01          60.0          12.0         7.2        13.0
#
#                Developer Rating
# 0               Nintendo      E
# 1               Nintendo      E
# 2               Nintendo      E
# 3               Nintendo      E
# 4               Nintendo      E
# ...                  ...    ...
# 6821       Fluid Studios      E
# 6822     Criterion Games      M
# 6823  Kojima Productions      M
# 6824        Atomic Games      T
# 6825              SimBin   E10+
#
# [6826 rows x 16 columns]
